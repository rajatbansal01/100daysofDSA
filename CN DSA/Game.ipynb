# %%
import random
def start_game():
    mat = []
    for i in range(4):
        mat.append([0]*4)
    
    return mat

def add_new_two(mat):
    r = random.randint(0,3)
    c = random.randint(0,3)
    
    while mat[r][c] != 0:
        r = random.randint(0,3)
        c = random.randint(0,3)
    mat[r][c] = 2
    
def current_state(mat):
    
    # if Won
    for i in range(4):
        for j in range(4):
            if [i][j] == 2048:
                return "WON"
            
    # Still going on
    
    # If any zero is present
    for i in range(4):
        for j in range(4):
            if mat[i][j] == 0:
                return "STILL GOING ON"
            
    # if two same numbers are present (except the last row ans last column)
    
    for i in range(3):
        for j in range(3):
            if mat[i][j] == mat[i+1][j] or mat[i][j] == mat[i][j+1]:
                return "STILL GOING ON"
    
    # If same present at the last row
    
    for j in range(3):
        if mat[3][j] == mat[3][j+1]:
            return "STILL GOING ON"
        
    # if same present at the last column
    
    for i in range(3):
        if mat[i][3] == mat[i+1][3]:
            return "STILL GOING ON"
        
    return "LOST"

def compress(mat):
    changed = False
    new_mat = []
    for i in range(4):
        new_mat.append([0]*4)
        
    for i in range(4):
        pos = 0
        for j in range(4):
            if mat[i][j] != 0:
                new_mat[i][pos] = mat[i][j]
                if pos != j:
                    changed = True
                pos+=1
    return new_mat , changed

# Left Merge
def merge(mat):
    changed = False
    for i in range(4):
        for j in range(3):
            if mat[i][j] == mat[i][j+1] and mat[i][j] != 0:
                changed = True
                mat[i][j] = 2*mat[i][j]
                mat[i][j+1] = 0
                
## Reverse Function : That reverse the direction of rows i.e left to right

def reverse(mat):
    new_mat = []
    
    for i in range(4):
        new_mat.append([])
        for j in range(4):
            new_mat[i].append(mat[i][3-j])
            
    return new_mat

def transpose(mat):
    new_mat = []
    for i in range(4):
        new_mat.append([])
        for j in range(4):
            new_mat[i].append(mat[j][i])
    return new_mat

# left move

def left_move(mat):
    mat = compress(mat)
    merge(mat)
    mat = compress(mat)
return mat
# Out:
#   File "C:\Users\HP\AppData\Local\Temp/ipykernel_9144/2826756576.py", line 99
#
#     ^
# SyntaxError: unexpected EOF while parsing
